# %% [markdown]
# ### 1. Crear un entorno de anaconda con los paquetes que considere necesarios.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style("white")
import matplotlib.pyplot as plt
d = np.load('proyecto_training_data.npy') 
df = pd.DataFrame(d)
df
# Out:
#              0    1       2    3       4     5
# 0     208500.0  7.0   856.0  8.0  2003.0  65.0
# 1     181500.0  6.0  1262.0  6.0  1976.0  80.0
# 2     223500.0  7.0   920.0  6.0  2001.0  68.0
# 3     140000.0  7.0   961.0  7.0  1915.0  60.0
# 4     250000.0  8.0  1145.0  9.0  2000.0  84.0
# ...        ...  ...     ...  ...     ...   ...
# 1455  175000.0  6.0   953.0  7.0  1999.0  62.0
# 1456  210000.0  6.0  2073.0  7.0  1978.0  85.0
# 1457  266500.0  7.0  1188.0  9.0  1941.0  66.0
# 1458  142125.0  5.0  1078.0  5.0  1950.0  68.0
# 1459  147500.0  5.0  1256.0  6.0  1965.0  75.0
#
# [1460 rows x 6 columns]

# %% [markdown]
# ### 2. Usando sclicing con NumPy separar los datos en 2 datasets: entrenamiento(80 %) y validación y pruebas(20 %).

# %%
Porcentaje = int(df[0].count()*.8)
Porcentaje
# Out:
# 1168

# %%
Set_Entrenamiento = df.iloc[:Porcentaje]
Set_Entrenamiento.set_axis(['SalePrice', 'OverallQual', 'First Floor square feet','Total rooms above grade', 
                            'Original construction date', 'Linear feet of street connected to property'], 
                    axis='columns', inplace=True)
Set_Entrenamiento
# Out:
#       SalePrice  OverallQual  First Floor square feet  \
# 0      208500.0          7.0                    856.0
# 1      181500.0          6.0                   1262.0
# 2      223500.0          7.0                    920.0
# 3      140000.0          7.0                    961.0
# 4      250000.0          8.0                   1145.0
# ...         ...          ...                      ...
# 1163   108959.0          4.0                   1258.0
# 1164   194000.0          5.0                   1432.0
# 1165   233170.0          7.0                   1502.0
# 1166   245350.0          8.0                   1694.0
# 1167   173000.0          6.0                    959.0
#
#       Total rooms above grade  Original construction date  \
# 0                         8.0                      2003.0
# 1                         6.0                      1976.0
# 2                         6.0                      2001.0
# 3                         7.0                      1915.0
# 4                         9.0                      2000.0
# ...                       ...                         ...
# 1163                      6.0                      1969.0
# 1164                      5.0                      1978.0
# 1165                      7.0                      2009.0
# 1166                      7.0                      2008.0
# 1167                      7.0                      2000.0
#
#       Linear feet of street connected to property
# 0                                            65.0
# 1                                            80.0
# 2                                            68.0
# 3                                            60.0
# 4                                            84.0
# ...                                           ...
# 1163                                         60.0
# 1164                                          NaN
# 1165                                         79.0
# 1166                                         64.0
# 1167                                         58.0
#
# [1168 rows x 6 columns]

# %%
Set_Pruebas = df.iloc[Porcentaje:]
Set_Pruebas.set_axis(['SalePrice', 'OverallQual', 'First Floor square feet','Total rooms above grade', 
                      'Original construction date', 'Linear feet of street connected to property'], axis='columns', inplace=True)
Set_Pruebas
# Out:
#       SalePrice  OverallQual  First Floor square feet  \
# 1168   235000.0          6.0                   1236.0
# 1169   625000.0         10.0                   1831.0
# 1170   171000.0          6.0                   1118.0
# 1171   163000.0          6.0                   1261.0
# 1172   171900.0          7.0                    625.0
# ...         ...          ...                      ...
# 1455   175000.0          6.0                    953.0
# 1456   210000.0          6.0                   2073.0
# 1457   266500.0          7.0                   1188.0
# 1458   142125.0          5.0                   1078.0
# 1459   147500.0          5.0                   1256.0
#
#       Total rooms above grade  Original construction date  \
# 1168                      7.0                      1935.0
# 1169                     10.0                      1995.0
# 1170                      6.0                      1977.0
# 1171                      6.0                      1958.0
# 1172                      5.0                      2006.0
# ...                       ...                         ...
# 1455                      7.0                      1999.0
# 1456                      7.0                      1978.0
# 1457                      9.0                      1941.0
# 1458                      5.0                      1950.0
# 1459                      6.0                      1965.0
#
#       Linear feet of street connected to property
# 1168                                        120.0
# 1169                                        118.0
# 1170                                         76.0
# 1171                                         76.0
# 1172                                         35.0
# ...                                           ...
# 1455                                         62.0
# 1456                                         85.0
# 1457                                         66.0
# 1458                                         68.0
# 1459                                         75.0
#
# [292 rows x 6 columns]

# %% [markdown]
# ### 3. Análisis exploratorio de datos: Para cada variable en el dataset calcular((usando numpy o pandas):
#
#    * Media
#    * Valor máximo
#    * Valor mínimo
#    * Rango(peak to peak, no el rango del tensor que por ser vector sabemos que es 1)
#    * Desviación estándar.

# %%
Media = Set_Entrenamiento.mean(axis=0)
Valor_Maximo =  Set_Entrenamiento.max(axis=0)
Valor_Minimo = Set_Entrenamiento.min(axis=0)
Desviacion_Estandar = Set_Entrenamiento.std(axis=0)
Rango = Set_Entrenamiento.ndim

Resultados = ({'Media':pd.Series(Media,dtype=float), 'Valor_Maximo':pd.Series(Valor_Maximo,dtype=float), 'Valor_Minimo':pd.Series(Valor_Minimo,dtype=float),
             'Desviacion_Estandar':pd.Series(Desviacion_Estandar,dtype=float), 'Rango':pd.Series(Rango)})
dfAnalisis = pd.DataFrame(Resultados)
dfAnalisis
# Out:
#                                                      Media  Valor_Maximo  \
# 0                                                      NaN           NaN
# First Floor square feet                        1156.323630        3228.0
# Linear feet of street connected to property      69.946985         313.0
# Original construction date                     1971.451199        2010.0
# OverallQual                                       6.101027          10.0
# SalePrice                                    180590.277397      755000.0
# Total rooms above grade                           6.485445          14.0
#
#                                              Valor_Minimo  \
# 0                                                     NaN
# First Floor square feet                             334.0
# Linear feet of street connected to property          21.0
# Original construction date                         1875.0
# OverallQual                                           1.0
# SalePrice                                         34900.0
# Total rooms above grade                               2.0
#
#                                              Desviacion_Estandar  Rango
# 0                                                            NaN    2.0
# First Floor square feet                               373.780374    NaN
# Linear feet of street connected to property            23.478161    NaN
# Original construction date                             29.951707    NaN
# OverallQual                                             1.378025    NaN
# SalePrice                                           78815.697902    NaN
# Total rooms above grade                                 1.609141    NaN

# %%
Set_Entrenamiento.describe()
# Out:
#            SalePrice  OverallQual  First Floor square feet  \
# count    1168.000000  1168.000000              1168.000000
# mean   180590.277397     6.101027              1156.323630
# std     78815.697902     1.378025               373.780374
# min     34900.000000     1.000000               334.000000
# 25%    129900.000000     5.000000               882.000000
# 50%    162950.000000     6.000000              1086.000000
# 75%    214000.000000     7.000000              1390.250000
# max    755000.000000    10.000000              3228.000000
#
#        Total rooms above grade  Original construction date  \
# count              1168.000000                 1168.000000
# mean                  6.485445                 1971.451199
# std                   1.609141                   29.951707
# min                   2.000000                 1875.000000
# 25%                   5.000000                 1954.000000
# 50%                   6.000000                 1973.000000
# 75%                   7.000000                 2000.000000
# max                  14.000000                 2010.000000
#
#        Linear feet of street connected to property
# count                                   962.000000
# mean                                     69.946985
# std                                      23.478161
# min                                      21.000000
# 25%                                      59.000000
# 50%                                      70.000000
# 75%                                      80.000000
# max                                     313.000000

# %% [markdown]
# ### 4. Para cada variable en el dataset usar seaborn para graficar un histograma de la variable.

# %%
for i in Set_Entrenamiento.columns.values:
    ax = sns.displot(Set_Entrenamiento[i], edgecolor='k', color="#58ACFA")
    plt.xlabel(i)
    plt.ylabel('Conteo')
    plt.show()

# %% [markdown]
# ### 5. Para cada variable independiente x :
#    * Calcular el coeficiente de correlación entre x y y.
#    * Graficar x vs y(scatterplot) usando matplotlib.
#    * Colocar el coeficiente de correlación y colocarlo como parte del título  de la gráfica.
#    * Basado en la gráfica y el coeficiente de correlación de cada par x,y elegir las 2 variables con más potencial predictivo es decir las 2 variables que presentan mayor correlación entre dicha variable y la variable dependiente.

# %%
Correlaciones = []
for i in Set_Entrenamiento.columns.values:
    Correlacion = (pd.DataFrame(Set_Entrenamiento[[i,'SalePrice']]).corr().iloc[0,1])
    Correlaciones.append(Correlacion)
    plt.scatter(Set_Entrenamiento[i], Set_Entrenamiento['SalePrice'], edgecolor='k', color="#58ACFA")
    plt.title(str(i)+' vs ' + str('SalePrice') + ' / Corr:  '+str((Correlacion)))
    plt.show()

# %%
sns.pairplot(Set_Entrenamiento)

# %%
Mejor_Potencial = pd.DataFrame({'Correlaciones':Correlaciones},index=[Set_Entrenamiento.columns.values])
Mejor_Potencial
# Out:
#                                              Correlaciones
# SalePrice                                         1.000000
# OverallQual                                       0.793990
# First Floor square feet                           0.616289
# Total rooms above grade                           0.564707
# Original construction date                        0.534171
# Linear feet of street connected to property       0.363292

# %%
print('Las 2 mejores variables de coeficiente de correlación son: ')
Mejor_Potencial['Correlaciones'].nlargest(3)[1:3]
# Out:
# Las 2 mejores variables de coeficiente de correlación son:
# OverallQual                0.793990
# First Floor square feet    0.616289
# Name: Correlaciones, dtype: float64

# %%
class My_regresion():
    #Constructor
    def __init__(self, x, y, epochs, imprimir_error_cada, learning_rate):
        self.x = x
        self.y = y
        self.b0 = 0
        self.b1 = 1
        self.Error = []
        self.Modelo = {}  
        self.VectorY = np.reshape(self.y, (-1,1))
        self.VectorUnos = np.ones_like(self.x).reshape(-1,1)
        self.VectorXUnos = np.hstack([np.reshape(self.x,(-1,1)),self.VectorUnos])
        self.betas = ([[self.b1],[self.b0]])

      
        for i in range(epochs):
            self.y_hat = np.dot(self.VectorXUnos, self.betas)
            self.Errores = 1/(2*self.VectorY.shape[0]) * sum((self.VectorY - self.y_hat)**2)
            self.Error.append(self.Errores[0])

            self.gradiante = (learning_rate*(1/self.VectorY.shape[0]*sum((self.y_hat - self.VectorY)*self.VectorXUnos)))
            self.gradiante = self.gradiante.reshape((-1,1))
            self.betas = self.betas - self.gradiante
            
            self.Modelo[i] = [self.betas, self.y_hat, self.VectorY, self.x]
            
            if i%imprimir_error_cada==0:
                print('\nNumero de Iteración: ', i)
                print('Error: ',self.Errores[0])
        
    def modelo(self):
        return self.Modelo , np.array(self.Error)

    @staticmethod
    def error(error):
        fig_1 = plt.figure(figsize=(9,7))
        ax_2 = fig_1.add_axes([0.1, 0.1, 1, 1])
        ax_2.plot(error, color="#58ACFA")
        ax_2.set_title("Errores del modelo")
        ax_2.set_xlabel("Numero de Iteraciones")
        ax_2.set_ylabel('Error')
        plt.show()
        
    @staticmethod
    def evolucion(modelo,n):
        for i in range(len(modelo)):
            if i%n == 0:
                plt.figure(figsize = (6,5))
                plt.scatter(x = modelo[i][3], y = modelo[i][2], color = '#CDCDCD')
                plt.plot(modelo[i][3],  modelo[i][1], linestyle ='solid', color ='b')
                plt.title("Modelo #"+str(i), fontsize = 12)
                plt.xlabel("X", fontsize = 10)
                plt.ylabel("Y", fontsize = 10)
                plt.xticks(fontsize = 10)
                plt.yticks(fontsize = 10)
                plt.show()

# %%
NPSales = np.reshape(np.array(Set_Entrenamiento['SalePrice']), (-1, 1))
NPOverallQual = np.reshape(np.array(Set_Entrenamiento['OverallQual']), (-1, 1))
NPFirst_Floor_square_feet = np.reshape(np.array(Set_Entrenamiento['First Floor square feet']), (-1, 1))
Epoch = 10000
Imprimir = 4000
Escalar = 0.01
Regresion = My_regresion(NPOverallQual, 
                     NPSales, 
                     Epoch,Imprimir,Escalar)
Rmodelos, Rerrores = Regresion.modelo()
# Out:
# Numero de Iteración:  0
# Error:  19408534125.107876
#
# Numero de Iteración:  4000
# Error:  1152523929.6840253
#
# Numero de Iteración:  8000
# Error:  1147043095.7068453

# %%
Regresion.error(Rerrores)
